# %%
import matplotlib.pyplot as plt

#Sample data for energy consumption over 6 months (in Mich)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
energy_consumption= [1200, 1300, 1100, 1500, 1400, 1600]

#Create a Line plot
plt.plot(months, energy_consumption, marker='o', color='b', linestyle='--')

#Add titles and Labels
plt.title('Energy Consumption Over 6 Months')
plt.xlabel('Month')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
# Somple data for energy consumption by different renewable sources
energy_sources = ['Solar', 'Wind', 'Hydropower', 'Biomass']
energy_values = [1200, 3400, 2900, 2500]

#Create a bar chart
plt.bar(energy_sources, energy_values, color="green")

#Add titles and Labels
plt.title("Energy Consumption by Renewable Energy Source")
plt.xlabel('Energy Source')
plt.ylabel("Energy Consumption (MWh)")
plt.show()

# %%
#Pie chart to show energy consumption distribution
plt.pie(energy_values, labels=energy_sources, autopct='%1.1f%%', colors=['gold', 'lightblue', "lightgreen", 'coral'])

#Add a title
plt.title("Energy Consumption Share by Source")
plt.show()

# %%
# Sample data for energy consumption and carbon emissions
carbon_emissions = [400, 500, 450, 300, 350, 550] # in kg CO2

#Create a scatter plot
plt.scatter(energy_consumption, carbon_emissions, color='red')

#Add titles and Labels
plt.title('Energy Consumption vs Carbon Emissions')
plt.xlabel('Energy Consumption (MWh)')
plt.ylabel('Carbon Emissions (kg CO2)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
energy_sources = ['Solar', 'Wind', 'Hydropower', 'Geothermal', 'Biomass']
energy_consumption = [150, 200, 350, 300, 250]

# Create a bar plot
plt.bar(energy_sources, energy_consumption)

# Add titles and labels
plt.title('Customized Energy Consumption by Source', fontsize=14, fontweight='bold')
plt.xlabel('Energy Source', fontsize=12)
plt.ylabel('Energy Consumption (MWh)', fontsize=12)

# Adding grid and customizing style
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(['Energy Consumption'], loc='upper left')

# Show the plot
plt.show()

# %%
#Histogram
"""
What is a Histogram?
A histogram is a graphical representation of the distribution of a set of data. 
It is a type of bar chart that shows the frequency or density of data points within 
a specified range or bin. Histograms are useful for understanding the shape and 
spread of a dataset, and for identifying patterns or outliers.

Types of Histograms:
Frequency Histogram: Shows the number of data points within each bin.
Density Histogram: Shows the proportion of data points within each bin.
Relative Frequency Histogram: Shows the proportion of data points within each bin, as a percentage.
Need for Histogram:

Histograms are useful in various fields, including:
Data Analysis: Histograms help to understand the distribution of data, identify patterns, and detect outliers.
Data Visualization: Histograms provide a visual representation of data, making it easier to understand and communicate insights.
Statistics: Histograms are used to calculate measures of central tendency (mean, median, mode) and measures of variability (range, interquartile range).
Machine Learning: Histograms are used to visualize the distribution of data, which is essential for many machine learning algorithms.
import matplotlib.pyplot as plt
"""
import numpy as np

data = np.random.normal(170, 10, 250) #(mean, sd, number of samples) #The hist() function will read the array and produce a histogram:
#set the bin value 30, A bin in a histogram represents a range of values
#plt.hist(data);

#plt.show()
plt.hist(data, bins=10);

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#double line chart

#Y-axis values
y1= [2, 3, 4.5]

#Y-axis values
y2= [1, 1.5, 5]

#Function to plot
plt.plot(y1)
plt.plot(y2)

#Function add a Legend
plt.legend(["blue", "green"], loc ="lower right")

#function to show the plot
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#Creating a DataFrame for pair plot
data = {
"Solar": [1200, 1500, 1300],
"Wind": [3400, 3600, 3200],
"Hydropower": [2900, 3100, 2800],
"Blomass": [2500, 2700, 2400]
}

df =pd.DataFrame(data)
#Ceate a pair plot 
sns.pairplot(df)
plt.show()

# %%
#Create a heatmap to show the correlation matrix
correlation_matrix = df.corr()

#Plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

#Add title
plt.title('Correlation Between Energy Sources')
plt.show()

# %%
# Create a box plot
sns.boxplot(data=df)

#Add title
plt.title('Distribution of Energy Consumption by Source')
plt.show()

# %%
# Create a violin plot
sns.violinplot(data=df)

#Add title
plt.title('Violin Plot of Energy Consumption Distributions')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Sample data for energy consumption and carbon emissions
energy_values = [100, 200, 300, 400, 500] #Replace with your actual date
carbon_emissions = [10, 20, 25, 40, 50] #Replace with your actual data
#Create a DataFrame with energy consumption and carbon emissions

df_reg = pd.DataFrame({
'Energy Consumption':energy_values,
'Carbon Emissions': carbon_emissions
})

#Create a regression plot
sns.regplot(x='Energy Consumption', y='Carbon Emissions', data = df_reg)

#Add title
plt.title('Energy Consumption vs Carbon Emissions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()

#USE TO CREATE A NEW FIG
ax plt.axes (projection ="3d")
# Out:
#   Cell In[68], line 7
#     ax plt.axes (projection ="3d")
#        ^
# SyntaxError: invalid syntax

# %%
#importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()

# Syntax for 3d projection
ax = plt.axes(projection ="3d")

# defining all 3 axes
z = np.linspace(0, 1, 1000)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
